# %% [markdown]
# # v1 - 基礎模型建立

# %%
# !nvidia-smi
# !pip install -U git+https://github.com/qubvel/efficientnet

# %%
# %tensorflow_version 2.x
import zipfile
import os
import csv
import numpy as np
import shutil
from tqdm.auto import tqdm
import matplotlib.pyplot as plt

# %%
IMAGE_SIZE = 224
BATCH_SIZE = 8
STEPS = 64
NUM_EPOCHS = 40
NUM_CLASSES = 3
DATASET_PATH = '/content/C1-P1_Train_Dev/C1-P1/'       # 資料路徑

# %% [markdown]
# # 載入、分類資料

# %%
def image_class():
    train_test_split = 0.2

    f = zipfile.ZipFile("/content/drive/My Drive/Colab Notebooks/AIMango_sample/C1-P1_Train_Dev.zip")
    f.extractall("./")

    # 依分類建立資料夾
    if not os.path.isdir(DATASET_PATH + 'A'):
        os.mkdir(DATASET_PATH + 'A')
    if not os.path.isdir(DATASET_PATH + 'B'):
        os.mkdir(DATASET_PATH + 'B')
    if not os.path.isdir(DATASET_PATH + 'C'):
        os.mkdir(DATASET_PATH + 'C')
    
    with open('/content/C1-P1_Train_Dev/C1-P1.csv') as csvfile:
        rows = csv.reader(csvfile)

        level_path = {'A': [], 'B': [], 'C': []}
        for row in rows:
            level_path[row[1][-1]].append(DATASET_PATH + row[0])

        for lvl in level_path:            
            for i, img_path in enumerate(tqdm(level_path[lvl])):
                shutil.move(img_path, DATASET_PATH + lvl)
                
if not os.path.exists('/content/C1-P1_Train_Dev'):
    image_class()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=2035.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2361.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2004.0), HTML(value='')))

# %% [markdown]
# # 載入、處理影像
#     1. Normalized to 0 - 1
#     2. resize
#     3. Split train、label
#     4. label do One-Hot encoding
#     5. train_test_split

# %%
from glob import glob
import cv2

class_map = {'A': 0, 'B': 1, 'C': 2}
IMG_PATH = glob('/content/C1-P1_Train_Dev/C1-P1/*/*.jpg')
np.random.shuffle(IMG_PATH) # 打亂順序

data_count = len(IMG_PATH)
X_dataset = np.zeros((data_count, IMAGE_SIZE, IMAGE_SIZE, 3)).astype('float32')
Y_dataset = np.zeros((data_count, )).astype('float32')

for i, path in enumerate(tqdm(IMG_PATH)):
    img = cv2.imread(path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = img / 255.
    img_resize = cv2.resize(img, (IMAGE_SIZE, IMAGE_SIZE)).astype('float32')
    cls = path.split('/')[-2]
    
    X_dataset[i] = img_resize
    Y_dataset[i] = class_map[cls]
# Out:
# HBox(children=(FloatProgress(value=0.0, max=6400.0), HTML(value='')))

# %%
import pandas as pd

unique, counts = np.unique(Y_dataset, return_counts=True)
pd.DataFrame(counts, index = ['A', 'B', 'C'])
# Out:
#       0
# A  2035
# B  2361
# C  2004

# %%
from tensorflow.keras.utils import to_categorical

y_onehot = to_categorical(Y_dataset, num_classes=NUM_CLASSES, dtype='uint8')

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X_dataset, y_onehot, test_size=0.2, random_state=123)

# %% [markdown]
# # CNN、FC 模型建立

# %%
import efficientnet.tfkeras as efn
from tensorflow.keras import Model
import tensorflow.keras.layers as L

net = efn.EfficientNetB7(input_shape=(IMAGE_SIZE, IMAGE_SIZE, 3),
                         weights='noisy-student',
                         include_top=False)

x = net.output
x = L.Flatten()(x)
x = L.Dropout(0.5)(x)
x = L.Dense(NUM_CLASSES, activation='softmax')(x)

model = Model(inputs=net.input, outputs=x)
# Out:
# Downloading data from https://github.com/qubvel/efficientnet/releases/download/v0.0.1/efficientnet-b7_noisy-student_notop.h5
# 258072576/258068648 [==============================] - 3s 0us/step

# %% [markdown]
# # 模型編譯 optimizer、loss、metrics

# %%
from tensorflow.keras.optimizers import Adam

model.compile(optimizer=Adam(),
              loss='categorical_crossentropy',
              metrics=['categorical_accuracy'])

# %% [markdown]
# # 模型訓練

# %%
history = model.fit(x_train, y_train,
                    batch_size=BATCH_SIZE,
                    epochs=NUM_EPOCHS,
                    verbose=1,
                    validation_split=0.2)
# Out:
# Epoch 1/40
# 512/512 [==============================] - 185s 361ms/step - loss: 4.7570 - categorical_accuracy: 0.4446 - val_loss: 7.0717 - val_categorical_accuracy: 0.4072
# Epoch 2/40
# 512/512 [==============================] - 180s 352ms/step - loss: 3.5385 - categorical_accuracy: 0.5508 - val_loss: 2.1424 - val_categorical_accuracy: 0.6426
# Epoch 3/40
# 512/512 [==============================] - 179s 349ms/step - loss: 3.2335 - categorical_accuracy: 0.5605 - val_loss: 31.2107 - val_categorical_accuracy: 0.5107
# Epoch 4/40
# 512/512 [==============================] - 180s 352ms/step - loss: 2.9410 - categorical_accuracy: 0.6042 - val_loss: 3.3891 - val_categorical_accuracy: 0.5879
# Epoch 5/40
# 512/512 [==============================] - 181s 353ms/step - loss: 2.4291 - categorical_accuracy: 0.6265 - val_loss: 2.3008 - val_categorical_accuracy: 0.5840
# Epoch 6/40
# 512/512 [==============================] - 181s 353ms/step - loss: 2.2322 - categorical_accuracy: 0.6411 - val_loss: 4.1950 - val_categorical_accuracy: 0.5947
# Epoch 7/40
# 512/512 [==============================] - 178s 348ms/step - loss: 2.6905 - categorical_accuracy: 0.5923 - val_loss: 95.5138 - val_categorical_accuracy: 0.5371
# Epoch 8/40
# 512/512 [==============================] - 180s 352ms/step - loss: 2.4760 - categorical_accuracy: 0.6140 - val_loss: 4.2582 - val_categorical_accuracy: 0.4746
# Epoch 9/40
# 512/512 [==============================] - 181s 353ms/step - loss: 2.1358 - categorical_accuracy: 0.6111 - val_loss: 1.2853 - val_categorical_accuracy: 0.6826
# Epoch 10/40
# 512/512 [==============================] - 178s 347ms/step - loss: 2.0756 - categorical_accuracy: 0.6174 - val_loss: 1.2393 - val_categorical_accuracy: 0.7012
# Epoch 11/40
# 512/512 [==============================] - 179s 350ms/step - loss: 2.6114 - categorical_accuracy: 0.5242 - val_loss: 2.9647 - val_categorical_accuracy: 0.5146
# Epoch 12/40
# 512/512 [==============================] - 177s 345ms/step - loss: 2.2159 - categorical_accuracy: 0.5347 - val_loss: 1.7066 - val_categorical_accuracy: 0.5000
# Epoch 13/40
# 512/512 [==============================] - 179s 351ms/step - loss: 1.9471 - categorical_accuracy: 0.5876 - val_loss: 16.7005 - val_categorical_accuracy: 0.5039
# Epoch 14/40
# 512/512 [==============================] - 181s 353ms/step - loss: 1.6034 - categorical_accuracy: 0.6069 - val_loss: 2.7079 - val_categorical_accuracy: 0.5625
# Epoch 15/40
# 512/512 [==============================] - 181s 353ms/step - loss: 1.7609 - categorical_accuracy: 0.6230 - val_loss: 1.4706 - val_categorical_accuracy: 0.6797
# Epoch 16/40
# 512/512 [==============================] - 178s 348ms/step - loss: 1.6031 - categorical_accuracy: 0.6345 - val_loss: 0.9258 - val_categorical_accuracy: 0.6992
# Epoch 17/40
# 512/512 [==============================] - 178s 348ms/step - loss: 1.7025 - categorical_accuracy: 0.6021 - val_loss: 0.8766 - val_categorical_accuracy: 0.6895
# Epoch 18/40
# 512/512 [==============================] - 180s 351ms/step - loss: 1.3880 - categorical_accuracy: 0.6448 - val_loss: 2.6637 - val_categorical_accuracy: 0.4883
# Epoch 19/40
# 512/512 [==============================] - 180s 352ms/step - loss: 1.2707 - categorical_accuracy: 0.6653 - val_loss: 1.1961 - val_categorical_accuracy: 0.6768
# Epoch 20/40
# 512/512 [==============================] - 179s 350ms/step - loss: 1.4428 - categorical_accuracy: 0.6521 - val_loss: 0.8756 - val_categorical_accuracy: 0.6885
# Epoch 21/40
# 512/512 [==============================] - 181s 354ms/step - loss: 1.3618 - categorical_accuracy: 0.6589 - val_loss: 1.2451 - val_categorical_accuracy: 0.6650
# Epoch 22/40
# 512/512 [==============================] - 179s 349ms/step - loss: 1.6116 - categorical_accuracy: 0.6443 - val_loss: 1.0454 - val_categorical_accuracy: 0.6641
# Epoch 23/40
# 512/512 [==============================] - 180s 351ms/step - loss: 1.4291 - categorical_accuracy: 0.6567 - val_loss: 1.2026 - val_categorical_accuracy: 0.6553
# Epoch 24/40
# 512/512 [==============================] - 180s 352ms/step - loss: 1.4419 - categorical_accuracy: 0.6455 - val_loss: 1.3385 - val_categorical_accuracy: 0.6211
# Epoch 25/40
# 512/512 [==============================] - 180s 352ms/step - loss: 1.0875 - categorical_accuracy: 0.6770 - val_loss: 0.8954 - val_categorical_accuracy: 0.6650
# Epoch 26/40
# 512/512 [==============================] - 180s 352ms/step - loss: 1.1236 - categorical_accuracy: 0.6816 - val_loss: 1.0945 - val_categorical_accuracy: 0.6162
# Epoch 27/40
# 512/512 [==============================] - 179s 350ms/step - loss: 1.3211 - categorical_accuracy: 0.6611 - val_loss: 1.3970 - val_categorical_accuracy: 0.5107
# Epoch 28/40
# 512/512 [==============================] - 180s 352ms/step - loss: 1.3272 - categorical_accuracy: 0.6372 - val_loss: 2.3836 - val_categorical_accuracy: 0.6260
# Epoch 29/40
# 512/512 [==============================] - 178s 348ms/step - loss: 1.4218 - categorical_accuracy: 0.6387 - val_loss: 7.7675 - val_categorical_accuracy: 0.7207
# Epoch 30/40
# 512/512 [==============================] - 178s 348ms/step - loss: 1.4857 - categorical_accuracy: 0.6138 - val_loss: 2.2613 - val_categorical_accuracy: 0.6543
# Epoch 31/40
# 512/512 [==============================] - 178s 348ms/step - loss: 1.3331 - categorical_accuracy: 0.6333 - val_loss: 1.0999 - val_categorical_accuracy: 0.6748
# Epoch 32/40
# 512/512 [==============================] - 181s 353ms/step - loss: 1.5816 - categorical_accuracy: 0.5527 - val_loss: 4.2104 - val_categorical_accuracy: 0.5107
# Epoch 33/40
# 512/512 [==============================] - 181s 353ms/step - loss: 1.5082 - categorical_accuracy: 0.5881 - val_loss: 39.7747 - val_categorical_accuracy: 0.5762
# Epoch 34/40
# 512/512 [==============================] - 178s 348ms/step - loss: 1.3788 - categorical_accuracy: 0.5986 - val_loss: 4.3184 - val_categorical_accuracy: 0.6826
# Epoch 35/40
# 512/512 [==============================] - 180s 352ms/step - loss: 1.2344 - categorical_accuracy: 0.6287 - val_loss: 4.9576 - val_categorical_accuracy: 0.6553
# Epoch 36/40
# 512/512 [==============================] - 181s 353ms/step - loss: 1.2829 - categorical_accuracy: 0.6184 - val_loss: 4.1887 - val_categorical_accuracy: 0.4668
# Epoch 37/40
# 512/512 [==============================] - 179s 350ms/step - loss: 1.1631 - categorical_accuracy: 0.6394 - val_loss: 6.9075 - val_categorical_accuracy: 0.6924
# Epoch 38/40
# 512/512 [==============================] - 179s 350ms/step - loss: 1.1524 - categorical_accuracy: 0.6511 - val_loss: 2.6333 - val_categorical_accuracy: 0.6895
# Epoch 39/40
# 512/512 [==============================] - 180s 352ms/step - loss: 1.3426 - categorical_accuracy: 0.6091 - val_loss: 837.1478 - val_categorical_accuracy: 0.3652
# Epoch 40/40
# 512/512 [==============================] - 181s 353ms/step - loss: 1.7248 - categorical_accuracy: 0.5234 - val_loss: 0.8993 - val_categorical_accuracy: 0.5889

# %% [markdown]
# # Plot accuracy

# %%
plt.plot(history.history['categorical_accuracy'])
plt.plot(history.history['val_categorical_accuracy'])
plt.legend(['acc', 'val_acc'])
plt.title('acc')
# Out:
# Text(0.5, 1.0, 'acc')

# %% [markdown]
# # Plot loss

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['loss', 'val_loss'])
plt.title('loss')
# Out:
# Text(0.5, 1.0, 'loss')

# %% [markdown]
# # 評估、預測模型

# %%
loss, acc = model.evaluate(x_test, y_test, steps=STEPS)
print('評估的準確率: ', acc)

ans = model.predict(x_test)
print('預測的結果: ', ans.argmax(axis=-1))
# Out:
# 64/64 [==============================] - 9s 144ms/step - loss: 0.9377 - categorical_accuracy: 0.5773
# 評估的準確率:  0.577343761920929
# 預測的結果:  [2 1 2 ... 2 0 1]
