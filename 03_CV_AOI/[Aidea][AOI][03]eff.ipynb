# %%
from google.colab import drive
drive.mount("/content/drive", force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !nvidia-smi
# !pip install -U git+https://github.com/qubvel/efficientnet
# Out:
# Sat Jun 20 01:07:27 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.36.06    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# Collecting git+https://github.com/qubvel/efficientnet
#   Cloning https://github.com/qubvel/efficientnet to /tmp/pip-req-build-rkmm8j45
#   Running command git clone -q https://github.com/qubvel/efficientnet /tmp/pip-req-build-rkmm8j45
# Requirement already satisfied, skipping upgrade: keras_applications<=1.0.8,>=1.0.7 in /usr/local/lib/python3.6/dist-packages (from efficientnet==1.1.0) (1.0.8)
# Requirement already satisfied, skipping upgrade: scikit-image in /usr/local/lib/python3.6/dist-packages (from efficientnet==1.1.0) (0.16.2)
# Requirement already satisfied, skipping upgrade: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras_applications<=1.0.8,>=1.0.7->efficientnet==1.1.0) (1.18.5)
# Requirement already satisfied, skipping upgrade: h5py in /usr/local/lib/python3.6/dist-packages (from keras_applications<=1.0.8,>=1.0.7->efficientnet==1.1.0) (2.10.0)
# Requirement already satisfied, skipping upgrade: pillow>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.1.0) (7.0.0)
# Requirement already satisfied, skipping upgrade: networkx>=2.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.1.0) (2.4)
# Requirement already satisfied, skipping upgrade: imageio>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.1.0) (2.4.1)
# Requirement already satisfied, skipping upgrade: scipy>=0.19.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.1.0) (1.4.1)
# Requirement already satisfied, skipping upgrade: matplotlib!=3.0.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.1.0) (3.2.1)
# Requirement already satisfied, skipping upgrade: PyWavelets>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.1.0) (1.1.1)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.6/dist-packages (from h5py->keras_applications<=1.0.8,>=1.0.7->efficientnet==1.1.0) (1.12.0)
# Requirement already satisfied, skipping upgrade: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx>=2.0->scikit-image->efficientnet==1.1.0) (4.4.2)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.1.0) (1.2.0)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.1.0) (0.10.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.1.0) (2.8.1)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.1.0) (2.4.7)
# Building wheels for collected packages: efficientnet
#   Building wheel for efficientnet (setup.py) ... done
#   Created wheel for efficientnet: filename=efficientnet-1.1.0-cp36-none-any.whl size=18327 sha256=44d2f0266ecc4c725379d815817c375fd9b857c71fae802bad4bd4b897e17ba6
#   Stored in directory: /tmp/pip-ephem-wheel-cache-otf17plc/wheels/64/60/2e/30ebaa76ed1626e86bfb0cc0579b737fdb7d9ff8cb9522663a
# Successfully built efficientnet
# Installing collected packages: efficientnet
# Successfully installed efficientnet-1.1.0

# %%
# %tensorflow_version 2.x

from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model
import tensorflow.keras.callbacks as cb
import tensorflow.keras.layers as L
import tensorflow.keras as K
import tensorflow as tf

from tqdm.auto import tqdm
from glob import glob
import efficientnet.tfkeras as efn
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os, zipfile, cv2, shutil

# tf.keras.backend.set_learning_phase(True)

# %%
IMAGE_SIZE = 224
BATCH_SIZE = 32
NUM_EPOCHS = 100
NUM_CLASSES = 6
train_images_path = '/content/train_images'       # 資料路徑
test_images_path = '/content/test_images'       # 資料路徑

# %% [markdown]
# # 資料載入

# %%
if not os.path.exists(train_images_path):
    f = zipfile.ZipFile("/content/drive/My Drive/AOI/train_images.zip")
    f.extractall("./")

if not os.path.exists(test_images_path):
    f = zipfile.ZipFile("/content/drive/My Drive/AOI/test_images.zip")
    f.extractall("./")

train_df = pd.read_csv('/content/drive/My Drive/AOI/train.csv')
test_df = pd.read_csv('/content/drive/My Drive/AOI/test.csv')

# %%
[os.makedirs(os.path.join(train_images_path, str(i)), exist_ok=True) for i in range(6)]
[os.makedirs(os.path.join(test_images_path, str(i)), exist_ok=True) for i in range(6)]

if len(glob(os.path.join(train_images_path, '*'))) > 10:
    for i, path in enumerate(train_df['ID']):
        src = os.path.join(train_images_path, path)
        dst = os.path.join(train_images_path, str(train_df['Label'][i]), path)
        shutil.move(src, dst)

# %% [markdown]
# # 資料增強

# %%
# [-1, 1]
def preprocess_fn1(im_array):
    return im_array / 127.5 -1

# [ 0, 1]
def preprocess_fn2(im_array):
    return im_array / 255

# 平均 / 標準差
def preprocess_fn3(im_array):
    return (im_array - np.mean(im_array))/ np.std(im_array)


trn_dagen = ImageDataGenerator(preprocessing_function= preprocess_fn1,
                               rotation_range=40,
                               horizontal_flip=True,
                               vertical_flip=True,
                            #    width_shift_range=0.1, 
                            #    height_shift_range=0.1, 
                            #    shear_range=0.1, 
                            #    zoom_range=0.1, 
                               validation_split=0.1)

trn_gen = trn_dagen.flow_from_directory(train_images_path,
                                        target_size=(IMAGE_SIZE, IMAGE_SIZE),
                                        batch_size=BATCH_SIZE,
                                        class_mode='categorical',
                                        subset='training',
                                        shuffle=True)

val_gen = trn_dagen.flow_from_directory(train_images_path,
                                        target_size=(IMAGE_SIZE, IMAGE_SIZE),
                                        batch_size=BATCH_SIZE,
                                        class_mode='categorical',
                                        subset='validation',
                                        shuffle=True)
# Out:
# Found 2277 images belonging to 6 classes.
# Found 251 images belonging to 6 classes.

# %% [markdown]
# # Callback 設置、模型建立、模型編譯、模型訓練

# %%
# 衰退學習率 (Learning rate)
rl_callback = cb.ReduceLROnPlateau(monitor   = "val_loss", 
                                   factor    = 0.5,
                                   patience  = 3, 
                                   verbose   = 0, 
                                   min_delta = 1e-4, 
                                   min_lr    = 1e-6)

es_callback = cb.EarlyStopping(patience=10, 
                               restore_best_weights=True)
callbacks = [
             rl_callback, 
             es_callback
             ]

STEP_SIZE_TRAIN = trn_gen.n // NUM_EPOCHS
STEP_SIZE_VALID = val_gen.n // NUM_EPOCHS

net = efn.EfficientNetB5(input_shape= (IMAGE_SIZE, IMAGE_SIZE, 3),
                         weights= 'noisy-student',
                         include_top= False)

for layer in net.layers: layer.trainable = True

x = net.output
x = L.GlobalAveragePooling2D()(x)
out = L.Dense(NUM_CLASSES, activation='softmax')(x)

model = Model(inputs=net.input, outputs=out)

model.compile(loss=K.losses.CategoricalCrossentropy(), 
              optimizer=K.optimizers.Adam(), 
              metrics=[K.metrics.CategoricalAccuracy()])

history = model.fit(trn_gen,
                    steps_per_epoch = STEP_SIZE_TRAIN,
                    epochs= NUM_EPOCHS,
                    verbose= 2, 
                    validation_data= val_gen,
                    validation_steps= STEP_SIZE_VALID,
                    callbacks= callbacks)
# Out:
# Epoch 1/100
# 22/22 - 19s - loss: 0.7131 - categorical_accuracy: 0.7681 - val_loss: 1.2871 - val_categorical_accuracy: 0.6719 - lr: 0.0010
# Epoch 2/100
# 22/22 - 17s - loss: 0.4071 - categorical_accuracy: 0.8920 - val_loss: 0.5663 - val_categorical_accuracy: 0.8281 - lr: 0.0010
# Epoch 3/100
# 22/22 - 16s - loss: 0.2485 - categorical_accuracy: 0.9318 - val_loss: 2.0064 - val_categorical_accuracy: 0.7031 - lr: 0.0010
# Epoch 4/100
# 22/22 - 16s - loss: 0.2051 - categorical_accuracy: 0.9542 - val_loss: 1.4178 - val_categorical_accuracy: 0.7812 - lr: 0.0010
# Epoch 5/100
# 22/22 - 16s - loss: 0.2142 - categorical_accuracy: 0.9403 - val_loss: 1.3230 - val_categorical_accuracy: 0.7969 - lr: 0.0010
# Epoch 6/100
# 22/22 - 15s - loss: 0.2061 - categorical_accuracy: 0.9468 - val_loss: 3.6331 - val_categorical_accuracy: 0.5781 - lr: 5.0000e-04
# Epoch 7/100
# 22/22 - 16s - loss: 0.1327 - categorical_accuracy: 0.9601 - val_loss: 1.4298 - val_categorical_accuracy: 0.7031 - lr: 5.0000e-04
# Epoch 8/100
# 22/22 - 16s - loss: 0.1449 - categorical_accuracy: 0.9631 - val_loss: 0.5615 - val_categorical_accuracy: 0.8438 - lr: 5.0000e-04
# Epoch 9/100
# 22/22 - 16s - loss: 0.1243 - categorical_accuracy: 0.9673 - val_loss: 0.3135 - val_categorical_accuracy: 0.8906 - lr: 5.0000e-04
# Epoch 10/100
# 22/22 - 16s - loss: 0.1153 - categorical_accuracy: 0.9773 - val_loss: 0.1498 - val_categorical_accuracy: 0.9844 - lr: 5.0000e-04
# Epoch 11/100
# 22/22 - 16s - loss: 0.0362 - categorical_accuracy: 0.9901 - val_loss: 0.2609 - val_categorical_accuracy: 0.9531 - lr: 5.0000e-04
# Epoch 12/100
# 22/22 - 16s - loss: 0.0494 - categorical_accuracy: 0.9844 - val_loss: 0.0082 - val_categorical_accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 13/100
# 22/22 - 16s - loss: 0.0514 - categorical_accuracy: 0.9901 - val_loss: 0.1234 - val_categorical_accuracy: 0.9531 - lr: 5.0000e-04
# Epoch 14/100
# 22/22 - 16s - loss: 0.0487 - categorical_accuracy: 0.9858 - val_loss: 0.0130 - val_categorical_accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 15/100
# 22/22 - 15s - loss: 0.1361 - categorical_accuracy: 0.9572 - val_loss: 0.0726 - val_categorical_accuracy: 0.9688 - lr: 5.0000e-04
# Epoch 16/100
# 22/22 - 16s - loss: 0.0479 - categorical_accuracy: 0.9858 - val_loss: 0.0522 - val_categorical_accuracy: 0.9844 - lr: 2.5000e-04
# Epoch 17/100
# 22/22 - 15s - loss: 0.0511 - categorical_accuracy: 0.9852 - val_loss: 0.1634 - val_categorical_accuracy: 0.9375 - lr: 2.5000e-04
# Epoch 18/100
# 22/22 - 16s - loss: 0.0395 - categorical_accuracy: 0.9872 - val_loss: 0.0949 - val_categorical_accuracy: 0.9531 - lr: 2.5000e-04
# Epoch 19/100
# 22/22 - 16s - loss: 0.0565 - categorical_accuracy: 0.9844 - val_loss: 0.0568 - val_categorical_accuracy: 0.9844 - lr: 1.2500e-04
# Epoch 20/100
# 22/22 - 16s - loss: 0.0503 - categorical_accuracy: 0.9844 - val_loss: 0.0021 - val_categorical_accuracy: 1.0000 - lr: 1.2500e-04
# Epoch 21/100
# 22/22 - 16s - loss: 0.0276 - categorical_accuracy: 0.9941 - val_loss: 0.0713 - val_categorical_accuracy: 0.9844 - lr: 1.2500e-04
# Epoch 22/100
# 22/22 - 16s - loss: 0.0329 - categorical_accuracy: 0.9897 - val_loss: 0.0158 - val_categorical_accuracy: 0.9844 - lr: 1.2500e-04
# Epoch 23/100
# 22/22 - 16s - loss: 0.0105 - categorical_accuracy: 0.9970 - val_loss: 0.0016 - val_categorical_accuracy: 1.0000 - lr: 1.2500e-04
# Epoch 24/100
# 22/22 - 16s - loss: 0.0250 - categorical_accuracy: 0.9915 - val_loss: 0.0093 - val_categorical_accuracy: 1.0000 - lr: 1.2500e-04
# Epoch 25/100
# 22/22 - 16s - loss: 0.0493 - categorical_accuracy: 0.9858 - val_loss: 0.0252 - val_categorical_accuracy: 0.9844 - lr: 1.2500e-04
# Epoch 26/100
# 22/22 - 16s - loss: 0.0282 - categorical_accuracy: 0.9915 - val_loss: 0.0011 - val_categorical_accuracy: 1.0000 - lr: 1.2500e-04
# Epoch 27/100
# 22/22 - 16s - loss: 0.0236 - categorical_accuracy: 0.9915 - val_loss: 0.0940 - val_categorical_accuracy: 0.9688 - lr: 1.2500e-04
# Epoch 28/100
# 22/22 - 16s - loss: 0.0239 - categorical_accuracy: 0.9901 - val_loss: 2.1398e-04 - val_categorical_accuracy: 1.0000 - lr: 1.2500e-04
# Epoch 29/100
# 22/22 - 16s - loss: 0.0170 - categorical_accuracy: 0.9943 - val_loss: 4.7730e-04 - val_categorical_accuracy: 1.0000 - lr: 1.2500e-04
# Epoch 30/100
# 22/22 - 16s - loss: 0.0395 - categorical_accuracy: 0.9867 - val_loss: 0.1191 - val_categorical_accuracy: 0.9688 - lr: 1.2500e-04
# Epoch 31/100
# 22/22 - 16s - loss: 0.0174 - categorical_accuracy: 0.9972 - val_loss: 0.0441 - val_categorical_accuracy: 0.9844 - lr: 1.2500e-04
# Epoch 32/100
# 22/22 - 16s - loss: 0.0142 - categorical_accuracy: 0.9970 - val_loss: 0.0383 - val_categorical_accuracy: 0.9688 - lr: 6.2500e-05
# Epoch 33/100
# 22/22 - 16s - loss: 0.0170 - categorical_accuracy: 0.9915 - val_loss: 0.0937 - val_categorical_accuracy: 0.9844 - lr: 6.2500e-05
# Epoch 34/100
# 22/22 - 16s - loss: 0.0270 - categorical_accuracy: 0.9943 - val_loss: 0.0165 - val_categorical_accuracy: 0.9844 - lr: 6.2500e-05
# Epoch 35/100
# 22/22 - 16s - loss: 0.0127 - categorical_accuracy: 0.9957 - val_loss: 2.0775e-04 - val_categorical_accuracy: 1.0000 - lr: 3.1250e-05
# Epoch 36/100
# 22/22 - 16s - loss: 0.0191 - categorical_accuracy: 0.9929 - val_loss: 7.8644e-04 - val_categorical_accuracy: 1.0000 - lr: 3.1250e-05
# Epoch 37/100
# 22/22 - 16s - loss: 0.0098 - categorical_accuracy: 0.9943 - val_loss: 0.1045 - val_categorical_accuracy: 0.9844 - lr: 3.1250e-05
# Epoch 38/100
# 22/22 - 16s - loss: 0.0395 - categorical_accuracy: 0.9915 - val_loss: 0.0358 - val_categorical_accuracy: 0.9844 - lr: 1.5625e-05
# Epoch 39/100
# 22/22 - 16s - loss: 0.0164 - categorical_accuracy: 0.9929 - val_loss: 0.0075 - val_categorical_accuracy: 1.0000 - lr: 1.5625e-05
# Epoch 40/100
# 22/22 - 16s - loss: 0.0226 - categorical_accuracy: 0.9929 - val_loss: 7.7470e-04 - val_categorical_accuracy: 1.0000 - lr: 1.5625e-05
# Epoch 41/100
# 22/22 - 16s - loss: 0.0146 - categorical_accuracy: 0.9957 - val_loss: 0.0974 - val_categorical_accuracy: 0.9844 - lr: 7.8125e-06
# Epoch 42/100
# 22/22 - 16s - loss: 0.0145 - categorical_accuracy: 0.9970 - val_loss: 0.0606 - val_categorical_accuracy: 0.9844 - lr: 7.8125e-06
# Epoch 43/100
# 22/22 - 16s - loss: 0.0268 - categorical_accuracy: 0.9943 - val_loss: 0.1144 - val_categorical_accuracy: 0.9688 - lr: 7.8125e-06
# Epoch 44/100
# 22/22 - 16s - loss: 0.0192 - categorical_accuracy: 0.9915 - val_loss: 3.7237e-04 - val_categorical_accuracy: 1.0000 - lr: 3.9063e-06
# Epoch 45/100
# 22/22 - 16s - loss: 0.0268 - categorical_accuracy: 0.9941 - val_loss: 0.0144 - val_categorical_accuracy: 0.9844 - lr: 3.9063e-06

# %% [markdown]
# # 觀察 Accuracy、Loss

# %%
epochs = range(1, len(history.history['categorical_accuracy']) + 1)

plt.figure(1, figsize = (15, 8)) 

plt.subplot(221)
plt.plot(epochs, history.history['categorical_accuracy'], linestyle='--')
plt.plot(epochs, history.history['val_categorical_accuracy'])
plt.ylabel('accuracy')  
plt.xlabel('epoch')
plt.title('model accuracy')  
plt.legend(['train', 'valid']) 

plt.subplot(222)
plt.plot(epochs, history.history['loss'], linestyle='--')
plt.plot(epochs, history.history['val_loss'], label = 'Validation Loss')
plt.title('model loss')  
plt.ylabel('loss')  
plt.xlabel('epoch')  
plt.legend(['train', 'valid']) 

plt.show()

# %% [markdown]
# # 預測

# %%
def predict_2(model, predict_df, image_path, x_col, y_col, batch_size=32, preprocessing_function=None):
    '''
        預測併儲存 csv
    '''
    # init
    model      = model
    predict_df = predict_df
    image_path = image_path
    batch_size = batch_size
    total_len  = len(predict_df[x_col]) // batch_size + 1

    def image_predict(image_id, batch_size=32):
        ''' 流程: 
            single image read
            img to array
            preprocessing
            append
        '''

        batch_img = []
        for imgid in image_id:
            img = load_img(os.path.join(image_path, imgid), target_size= (IMAGE_SIZE, IMAGE_SIZE))
            img = img_to_array(img)
            img = preprocessing_function(img)
            batch_img.append(img)
        
        batch_img = np.array(batch_img)
        pre = np.argmax(model.predict(batch_img), axis=1)
        return pre
    
    pic = 0
    for i in tqdm(range(total_len)):
        # image predict
        pre_list = image_predict(predict_df[x_col][pic: pic + batch_size])
        
        # to_csv
        for pre in pre_list:
            if len(predict_df[x_col]) > pic:
                predict_df[y_col][pic] = pre
                pic += 1

# 預測並寫入 csv
predict_2(model,
          test_df,
          test_images_path,
          x_col='ID',
          y_col='Label',
          batch_size=32,
          preprocessing_function= preprocess_fn1)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=317.0), HTML(value='')))
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# # 儲存 csv

# %%
test_df.to_csv('./test.csv')
