# %%
from google.colab import drive
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !nvidia-smi
# !pip install -U git+https://github.com/qubvel/efficientnet
# Out:
# Mon Jun 15 12:17:28 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.36.06    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   52C    P0    32W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# Collecting git+https://github.com/qubvel/efficientnet
#   Cloning https://github.com/qubvel/efficientnet to /tmp/pip-req-build-iu9oxdiu
#   Running command git clone -q https://github.com/qubvel/efficientnet /tmp/pip-req-build-iu9oxdiu
# Requirement already satisfied, skipping upgrade: keras_applications<=1.0.8,>=1.0.7 in /usr/local/lib/python3.6/dist-packages (from efficientnet==1.1.0) (1.0.8)
# Requirement already satisfied, skipping upgrade: scikit-image in /usr/local/lib/python3.6/dist-packages (from efficientnet==1.1.0) (0.16.2)
# Requirement already satisfied, skipping upgrade: h5py in /usr/local/lib/python3.6/dist-packages (from keras_applications<=1.0.8,>=1.0.7->efficientnet==1.1.0) (2.10.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras_applications<=1.0.8,>=1.0.7->efficientnet==1.1.0) (1.18.5)
# Requirement already satisfied, skipping upgrade: pillow>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.1.0) (7.0.0)
# Requirement already satisfied, skipping upgrade: scipy>=0.19.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.1.0) (1.4.1)
# Requirement already satisfied, skipping upgrade: networkx>=2.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.1.0) (2.4)
# Requirement already satisfied, skipping upgrade: imageio>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.1.0) (2.4.1)
# Requirement already satisfied, skipping upgrade: PyWavelets>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.1.0) (1.1.1)
# Requirement already satisfied, skipping upgrade: matplotlib!=3.0.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.1.0) (3.2.1)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.6/dist-packages (from h5py->keras_applications<=1.0.8,>=1.0.7->efficientnet==1.1.0) (1.12.0)
# Requirement already satisfied, skipping upgrade: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx>=2.0->scikit-image->efficientnet==1.1.0) (4.4.2)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.1.0) (2.8.1)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.1.0) (2.4.7)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.1.0) (0.10.0)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.1.0) (1.2.0)
# Building wheels for collected packages: efficientnet
#   Building wheel for efficientnet (setup.py) ... done
#   Created wheel for efficientnet: filename=efficientnet-1.1.0-cp36-none-any.whl size=18327 sha256=ca3fb66616d478fa9aad5ad58b65355716d10ee0a68d4e7d46d8ce156e963378
#   Stored in directory: /tmp/pip-ephem-wheel-cache-85vx5mp7/wheels/64/60/2e/30ebaa76ed1626e86bfb0cc0579b737fdb7d9ff8cb9522663a
# Successfully built efficientnet
# Installing collected packages: efficientnet
#   Found existing installation: efficientnet 1.1.0
#     Uninstalling efficientnet-1.1.0:
#       Successfully uninstalled efficientnet-1.1.0
# Successfully installed efficientnet-1.1.0

# %%
# %tensorflow_version 2.x

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.utils import plot_model
import tensorflow.keras.callbacks as cb
import tensorflow.keras.layers as L
import tensorflow.keras as K
import tensorflow as tf

import efficientnet.tfkeras as efn
import matplotlib.pyplot as plt
import numpy as np
from tqdm.auto import tqdm
from glob import glob
import os, zipfile, cv2, csv, shutil

# tf.keras.backend.set_learning_phase(True)

# %% [markdown]
# # 載入資料
#         # Coefficients:   width,depth,res,dropout
#         'efficientnet-b0': (1.0, 1.0, 224, 0.2),
#         'efficientnet-b1': (1.0, 1.1, 240, 0.2),
#         'efficientnet-b2': (1.1, 1.2, 260, 0.3),
#         'efficientnet-b3': (1.2, 1.4, 300, 0.3),
#         'efficientnet-b4': (1.4, 1.8, 380, 0.4),
#         'efficientnet-b5': (1.6, 2.2, 456, 0.4),
#         'efficientnet-b6': (1.8, 2.6, 528, 0.5),
#         'efficientnet-b7': (2.0, 3.1, 600, 0.5),

# %%
IMAGE_SIZE = 224
BATCH_SIZE = 32
NUM_EPOCHS = 100
STEPS = 128
NUM_CLASSES = 3
DATASET_PATH = '/content/datasets'       # 資料路徑

# %%
if not os.path.exists('datasets'):
    f = zipfile.ZipFile("/content/drive/My Drive/Colab Notebooks/datasets_9.zip")
    f.extractall("./")

# %% [markdown]
# # 資料增強 ImageDataGenerator

# %%
# [-1, 1]
def preprocess_fn1(im_array):
    return im_array / 127.5 -1

trn_dagen = ImageDataGenerator(rotation_range=40,
                               width_shift_range=0.2,
                               height_shift_range=0.2,
                            #    shear_range=0.1,
                            #    zoom_range=0.1,
                               horizontal_flip=True,
                               vertical_flip = True, 
                            #    brightness_range= [0.5, 1.5],
                               preprocessing_function= preprocess_fn1,
                               fill_mode='nearest')

trn_gen = trn_dagen.flow_from_directory(os.path.join(DATASET_PATH, 'train'),
                                        target_size=(IMAGE_SIZE, IMAGE_SIZE),
                                        batch_size=BATCH_SIZE,
                                        class_mode='categorical',
                                        shuffle=True)

val_eva_dagen = ImageDataGenerator(preprocessing_function= preprocess_fn1,
                                   validation_split=0.5)

val_gen = val_eva_dagen.flow_from_directory(os.path.join(DATASET_PATH, 'test'),
                                            target_size=(IMAGE_SIZE, IMAGE_SIZE),
                                            batch_size= BATCH_SIZE,
                                            class_mode='categorical',
                                            shuffle=True,
                                            subset='training')
                                            
eva_gen = val_eva_dagen.flow_from_directory(os.path.join(DATASET_PATH, 'test'),
                                            target_size=(IMAGE_SIZE, IMAGE_SIZE),
                                            batch_size= BATCH_SIZE * 3,
                                            class_mode='categorical',
                                            shuffle=True,
                                            subset='validation')
# Out:
# Found 7260 images belonging to 3 classes.
# Found 239 images belonging to 3 classes.
# Found 236 images belonging to 3 classes.

# %% [markdown]
# # 動態設計 Learning rate

# %%
def lrfn(epoch):
    LR_START = 0.0001
    LR_MAX = 0.00005
    LR_MIN = 0.0001
    LR_RAMPUP_EPOCHS = 4
    LR_SUSTAIN_EPOCHS = 6
    LR_EXP_DECAY = .8

    if epoch < LR_RAMPUP_EPOCHS:
        lr = (LR_MAX - LR_START) / LR_RAMPUP_EPOCHS * epoch + LR_START
    elif epoch < LR_RAMPUP_EPOCHS + LR_SUSTAIN_EPOCHS:
        lr = LR_MAX
    else:
        lr = (LR_MAX - LR_MIN) * LR_EXP_DECAY**(epoch - LR_RAMPUP_EPOCHS - LR_SUSTAIN_EPOCHS) + LR_MIN
    return lr
    
lr_callback = cb.LearningRateScheduler(lrfn, verbose=True)

rl_callback = cb.ReduceLROnPlateau(monitor = "val_loss", 
                                   factor = 0.1, 
                                   patience = 3, 
                                   verbose = 0, 
                                   mode = "auto", 
                                   min_delta = 1e-4, 
                                   cooldown = 0, 
                                   min_lr = 1e-7)

mc_callback = cb.ModelCheckpoint('drive/My Drive/ep{epoch:03d}-loss{loss:.3f}-val_loss{val_loss:.3f}.h5',
                                 monitor='val_loss',
                                 save_weights_only=True, 
                                 save_best_only=True, 
                                 save_freq=1)

es_callback = cb.EarlyStopping(patience=10, restore_best_weights=True)

# rng = [i for i in range(NUM_EPOCHS)]
# y = [lrfn(x) for x in rng]
# plt.plot(rng, y)
# print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))

callbacks = [lr_callback, 
             rl_callback, 
            #  mc_callback,
             es_callback
             ]

# %% [markdown]
# # CNN、FC 模型建立

# %%
net = efn.EfficientNetB5(input_shape= (IMAGE_SIZE, IMAGE_SIZE, 3),
                         include_top= False)

x = net.output
x = L.GlobalMaxPooling2D()(x)
out = L.Dense(NUM_CLASSES, activation='softmax')(x)

model = Model(inputs=net.input, outputs=out)

model.compile(loss=K.losses.CategoricalCrossentropy(), 
              optimizer=K.optimizers.Adam(learning_rate=1e-3, amsgrad=True), 
              metrics=[K.metrics.CategoricalAccuracy()])

STEP_SIZE_TRAIN = trn_gen.n // NUM_EPOCHS
STEP_SIZE_VALID = val_gen.n // NUM_EPOCHS

history = model.fit(trn_gen,
                    steps_per_epoch= STEP_SIZE_TRAIN,
                    epochs= 30,
                    verbose= 1,
                    validation_data= val_gen,
                    validation_steps= STEP_SIZE_VALID,
                    callbacks= callbacks)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 1/30
# 72/72 [==============================] - 73s 1s/step - loss: 1.6049 - categorical_accuracy: 0.4761 - val_loss: 1.5962 - val_categorical_accuracy: 0.4688 - lr: 1.0000e-04
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 8.75e-05.
# Epoch 2/30
# 72/72 [==============================] - 71s 981ms/step - loss: 1.0463 - categorical_accuracy: 0.6087 - val_loss: 1.0076 - val_categorical_accuracy: 0.6406 - lr: 8.7500e-05
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 7.500000000000001e-05.
# Epoch 3/30
# 72/72 [==============================] - 70s 975ms/step - loss: 0.9036 - categorical_accuracy: 0.6458 - val_loss: 1.0451 - val_categorical_accuracy: 0.6562 - lr: 7.5000e-05
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 6.25e-05.
# Epoch 4/30
# 72/72 [==============================] - 70s 972ms/step - loss: 0.8220 - categorical_accuracy: 0.6809 - val_loss: 0.7721 - val_categorical_accuracy: 0.7500 - lr: 6.2500e-05
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 5e-05.
# Epoch 5/30
# 72/72 [==============================] - 70s 979ms/step - loss: 0.7678 - categorical_accuracy: 0.6862 - val_loss: 0.6746 - val_categorical_accuracy: 0.7188 - lr: 5.0000e-05
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 5e-05.
# Epoch 6/30
# 72/72 [==============================] - 70s 972ms/step - loss: 0.7889 - categorical_accuracy: 0.6870 - val_loss: 0.7047 - val_categorical_accuracy: 0.7656 - lr: 5.0000e-05
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 5e-05.
# Epoch 7/30
# 72/72 [==============================] - 70s 968ms/step - loss: 0.7265 - categorical_accuracy: 0.7053 - val_loss: 0.6571 - val_categorical_accuracy: 0.7656 - lr: 5.0000e-05
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 5e-05.
# Epoch 8/30
# 72/72 [==============================] - 70s 975ms/step - loss: 0.6580 - categorical_accuracy: 0.7296 - val_loss: 0.4570 - val_categorical_accuracy: 0.8438 - lr: 5.0000e-05
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 5e-05.
# Epoch 9/30
# 72/72 [==============================] - 70s 974ms/step - loss: 0.6170 - categorical_accuracy: 0.7452 - val_loss: 0.6059 - val_categorical_accuracy: 0.7500 - lr: 5.0000e-05
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 5e-05.
# Epoch 10/30
# 72/72 [==============================] - 70s 971ms/step - loss: 0.6349 - categorical_accuracy: 0.7344 - val_loss: 0.5440 - val_categorical_accuracy: 0.7500 - lr: 5.0000e-05
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 5e-05.
# Epoch 11/30
# 72/72 [==============================] - 70s 967ms/step - loss: 0.6227 - categorical_accuracy: 0.7322 - val_loss: 0.6796 - val_categorical_accuracy: 0.7812 - lr: 5.0000e-05
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 6e-05.
# Epoch 12/30
# 72/72 [==============================] - 70s 967ms/step - loss: 0.5709 - categorical_accuracy: 0.7561 - val_loss: 0.5940 - val_categorical_accuracy: 0.7344 - lr: 6.0000e-05
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 6.8e-05.
# Epoch 13/30
# 72/72 [==============================] - 69s 953ms/step - loss: 0.5920 - categorical_accuracy: 0.7452 - val_loss: 0.5635 - val_categorical_accuracy: 0.8125 - lr: 6.8000e-05
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 7.439999999999999e-05.
# Epoch 14/30
# 72/72 [==============================] - 69s 956ms/step - loss: 0.5361 - categorical_accuracy: 0.7739 - val_loss: 0.5811 - val_categorical_accuracy: 0.7500 - lr: 7.4400e-05
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 7.952e-05.
# Epoch 15/30
# 72/72 [==============================] - 69s 956ms/step - loss: 0.5361 - categorical_accuracy: 0.7743 - val_loss: 0.5207 - val_categorical_accuracy: 0.7812 - lr: 7.9520e-05
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 8.361600000000001e-05.
# Epoch 16/30
# 72/72 [==============================] - 69s 953ms/step - loss: 0.5555 - categorical_accuracy: 0.7509 - val_loss: 0.5476 - val_categorical_accuracy: 0.7656 - lr: 8.3616e-05
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 8.68928e-05.
# Epoch 17/30
# 72/72 [==============================] - 69s 958ms/step - loss: 0.5346 - categorical_accuracy: 0.7704 - val_loss: 0.3917 - val_categorical_accuracy: 0.8125 - lr: 8.6893e-05
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 8.951424e-05.
# Epoch 18/30
# 72/72 [==============================] - 69s 952ms/step - loss: 0.5201 - categorical_accuracy: 0.7822 - val_loss: 0.4652 - val_categorical_accuracy: 0.7656 - lr: 8.9514e-05
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 9.161139199999999e-05.
# Epoch 19/30
# 72/72 [==============================] - 69s 953ms/step - loss: 0.5319 - categorical_accuracy: 0.7652 - val_loss: 0.5635 - val_categorical_accuracy: 0.7969 - lr: 9.1611e-05
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 9.32891136e-05.
# Epoch 20/30
# 72/72 [==============================] - 69s 955ms/step - loss: 0.4871 - categorical_accuracy: 0.7899 - val_loss: 0.5346 - val_categorical_accuracy: 0.7656 - lr: 9.3289e-05
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 9.463129088e-05.
# Epoch 21/30
# 72/72 [==============================] - 69s 954ms/step - loss: 0.4850 - categorical_accuracy: 0.7935 - val_loss: 0.4294 - val_categorical_accuracy: 0.7969 - lr: 9.4631e-05
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 9.5705032704e-05.
# Epoch 22/30
# 72/72 [==============================] - 69s 954ms/step - loss: 0.4793 - categorical_accuracy: 0.7960 - val_loss: 0.4155 - val_categorical_accuracy: 0.7969 - lr: 9.5705e-05
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 9.65640261632e-05.
# Epoch 23/30
# 72/72 [==============================] - 68s 951ms/step - loss: 0.4658 - categorical_accuracy: 0.7969 - val_loss: 0.4654 - val_categorical_accuracy: 0.7969 - lr: 9.6564e-05
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 9.725122093056e-05.
# Epoch 24/30
# 72/72 [==============================] - 69s 951ms/step - loss: 0.4674 - categorical_accuracy: 0.7995 - val_loss: 0.5266 - val_categorical_accuracy: 0.8281 - lr: 9.7251e-05
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 9.780097674444801e-05.
# Epoch 25/30
# 72/72 [==============================] - 69s 956ms/step - loss: 0.4529 - categorical_accuracy: 0.8025 - val_loss: 0.4952 - val_categorical_accuracy: 0.7656 - lr: 9.7801e-05
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 9.82407813955584e-05.
# Epoch 26/30
# 72/72 [==============================] - 68s 951ms/step - loss: 0.4637 - categorical_accuracy: 0.8070 - val_loss: 0.5830 - val_categorical_accuracy: 0.7344 - lr: 9.8241e-05
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 9.859262511644672e-05.
# Epoch 27/30
# 72/72 [==============================] - 69s 959ms/step - loss: 0.4332 - categorical_accuracy: 0.8112 - val_loss: 0.3740 - val_categorical_accuracy: 0.7812 - lr: 9.8593e-05
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 9.887410009315738e-05.
# Epoch 28/30
# 72/72 [==============================] - 69s 955ms/step - loss: 0.4261 - categorical_accuracy: 0.8170 - val_loss: 0.4916 - val_categorical_accuracy: 0.7812 - lr: 9.8874e-05
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 9.90992800745259e-05.
# Epoch 29/30
# 72/72 [==============================] - 69s 955ms/step - loss: 0.4102 - categorical_accuracy: 0.8247 - val_loss: 0.6455 - val_categorical_accuracy: 0.7188 - lr: 9.9099e-05
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 9.927942405962072e-05.
# Epoch 30/30
# 72/72 [==============================] - 69s 961ms/step - loss: 0.4319 - categorical_accuracy: 0.8125 - val_loss: 0.3987 - val_categorical_accuracy: 0.7969 - lr: 9.9279e-05

# %%
for layer in net.layers:
    layer.trainable = True

model.compile(loss=K.losses.CategoricalCrossentropy(), 
              optimizer=K.optimizers.Adam(learning_rate=1e-4, amsgrad=True), 
              metrics=[K.metrics.CategoricalAccuracy()])

STEP_SIZE_TRAIN = trn_gen.n // NUM_EPOCHS
STEP_SIZE_VALID = val_gen.n // NUM_EPOCHS

history = model.fit(trn_gen,
                    steps_per_epoch= STEP_SIZE_TRAIN,
                    epochs= 30,
                    verbose= 1,
                    validation_data= val_gen,
                    validation_steps= STEP_SIZE_VALID,
                    callbacks= callbacks)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 1/30
# 72/72 [==============================] - 73s 1s/step - loss: 0.4660 - categorical_accuracy: 0.8051 - val_loss: 0.3471 - val_categorical_accuracy: 0.8281 - lr: 1.0000e-04
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 8.75e-05.
# Epoch 2/30
# 72/72 [==============================] - 70s 970ms/step - loss: 0.4444 - categorical_accuracy: 0.8090 - val_loss: 0.3613 - val_categorical_accuracy: 0.8281 - lr: 8.7500e-05
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 7.500000000000001e-05.
# Epoch 3/30
# 72/72 [==============================] - 70s 966ms/step - loss: 0.3966 - categorical_accuracy: 0.8342 - val_loss: 0.3467 - val_categorical_accuracy: 0.8281 - lr: 7.5000e-05
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 6.25e-05.
# Epoch 4/30
# 72/72 [==============================] - 70s 967ms/step - loss: 0.4044 - categorical_accuracy: 0.8247 - val_loss: 0.4646 - val_categorical_accuracy: 0.7969 - lr: 6.2500e-05
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 5e-05.
# Epoch 5/30
# 72/72 [==============================] - 69s 962ms/step - loss: 0.4067 - categorical_accuracy: 0.8326 - val_loss: 0.3648 - val_categorical_accuracy: 0.8438 - lr: 5.0000e-05
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 5e-05.
# Epoch 6/30
# 72/72 [==============================] - 69s 964ms/step - loss: 0.3840 - categorical_accuracy: 0.8343 - val_loss: 0.4017 - val_categorical_accuracy: 0.8281 - lr: 5.0000e-05
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 5e-05.
# Epoch 7/30
# 72/72 [==============================] - 70s 966ms/step - loss: 0.3695 - categorical_accuracy: 0.8446 - val_loss: 0.4406 - val_categorical_accuracy: 0.8125 - lr: 5.0000e-05
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 5e-05.
# Epoch 8/30
# 72/72 [==============================] - 70s 966ms/step - loss: 0.3940 - categorical_accuracy: 0.8351 - val_loss: 0.4303 - val_categorical_accuracy: 0.7969 - lr: 5.0000e-05
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 5e-05.
# Epoch 9/30
# 72/72 [==============================] - 69s 964ms/step - loss: 0.3614 - categorical_accuracy: 0.8491 - val_loss: 0.2823 - val_categorical_accuracy: 0.9062 - lr: 5.0000e-05
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 5e-05.
# Epoch 10/30
# 72/72 [==============================] - 69s 952ms/step - loss: 0.3689 - categorical_accuracy: 0.8438 - val_loss: 0.4116 - val_categorical_accuracy: 0.8281 - lr: 5.0000e-05
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 5e-05.
# Epoch 11/30
# 72/72 [==============================] - 69s 953ms/step - loss: 0.3584 - categorical_accuracy: 0.8468 - val_loss: 0.3644 - val_categorical_accuracy: 0.8281 - lr: 5.0000e-05
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 6e-05.
# Epoch 12/30
# 72/72 [==============================] - 69s 957ms/step - loss: 0.3697 - categorical_accuracy: 0.8403 - val_loss: 0.3856 - val_categorical_accuracy: 0.8750 - lr: 6.0000e-05
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 6.8e-05.
# Epoch 13/30
# 72/72 [==============================] - 68s 951ms/step - loss: 0.3490 - categorical_accuracy: 0.8517 - val_loss: 0.4626 - val_categorical_accuracy: 0.7969 - lr: 6.8000e-05
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 7.439999999999999e-05.
# Epoch 14/30
# 72/72 [==============================] - 68s 947ms/step - loss: 0.3720 - categorical_accuracy: 0.8416 - val_loss: 0.5197 - val_categorical_accuracy: 0.7969 - lr: 7.4400e-05
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 7.952e-05.
# Epoch 15/30
# 72/72 [==============================] - 68s 940ms/step - loss: 0.3528 - categorical_accuracy: 0.8507 - val_loss: 0.2894 - val_categorical_accuracy: 0.8750 - lr: 7.9520e-05
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 8.361600000000001e-05.
# Epoch 16/30
# 72/72 [==============================] - 68s 939ms/step - loss: 0.3419 - categorical_accuracy: 0.8530 - val_loss: 0.5859 - val_categorical_accuracy: 0.7500 - lr: 8.3616e-05
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 8.68928e-05.
# Epoch 17/30
# 72/72 [==============================] - 67s 935ms/step - loss: 0.3323 - categorical_accuracy: 0.8568 - val_loss: 0.4346 - val_categorical_accuracy: 0.8594 - lr: 8.6893e-05
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 8.951424e-05.
# Epoch 18/30
# 72/72 [==============================] - 67s 937ms/step - loss: 0.3411 - categorical_accuracy: 0.8535 - val_loss: 0.3350 - val_categorical_accuracy: 0.8594 - lr: 8.9514e-05
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 9.161139199999999e-05.
# Epoch 19/30
# 72/72 [==============================] - 68s 944ms/step - loss: 0.3243 - categorical_accuracy: 0.8676 - val_loss: 0.4832 - val_categorical_accuracy: 0.8281 - lr: 9.1611e-05

# %% [markdown]
# # 模型編譯 optimizer、loss、metrics

# %%
# import tensorflow.keras as K

# model.compile(loss=K.losses.CategoricalCrossentropy(), 
#               optimizer=K.optimizers.Adam(learning_rate=1e-4, amsgrad=True), 
#               metrics=[K.metrics.CategoricalAccuracy()])

# STEP_SIZE_TRAIN = trn_gen.n // NUM_EPOCHS

# %% [markdown]
# # 模型訓練

# %%
# STEP_SIZE_TRAIN = trn_gen.n // NUM_EPOCHS

# history = model.fit(trn_gen,
#                     steps_per_epoch= STEP_SIZE_TRAIN,
#                     epochs= NUM_EPOCHS,
#                     verbose= 1,
#                     callbacks= callbacks)

# %%
model.save('/content/drive/My Drive/mango_v9-6.h5')

# %% [markdown]
# # Plot accuracy

# %%
plt.plot(history.history['categorical_accuracy'])
plt.plot(history.history['val_categorical_accuracy'])
plt.legend(['acc', 'val_acc'])
plt.title('acc')
# Out:
# Text(0.5, 1.0, 'acc')

# %% [markdown]
# # Plot loss

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['loss', 'val_loss'])
plt.title('loss')
# Out:
# Text(0.5, 1.0, 'loss')

# %% [markdown]
# # 評估模型

# %%
eva_x, eva_y = eva_gen.next()[0], eva_gen.next()[1]

# %%
loss, acc = model.evaluate(eva_gen, steps=STEPS)
print('評估的準確率: ', acc)
# Out:
#   3/128 [..............................] - ETA: 1:42 - loss: 0.4297 - categorical_accuracy: 0.8220WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 128 batches). You may need to use the repeat() function when building your dataset.
#   3/128 [..............................] - 2s 823ms/step - loss: 0.4297 - categorical_accuracy: 0.8220
# 評估的準確率:  0.8220338821411133

# %%
import pandas as pd
from sklearn.metrics import confusion_matrix

train, label = eva_gen.next()

pre = model.predict(train, steps= 1)
pre = pre.argmax(axis= -1)
label = label.argmax(axis= -1)

df = pd.DataFrame(confusion_matrix(label, pre))
df
# Out:
#     0  1   2
# 0  11  0   0
# 1   3  9   0
# 2   1  4  16
