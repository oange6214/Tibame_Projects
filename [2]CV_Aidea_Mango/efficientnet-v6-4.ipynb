# %%
from google.colab import drive
drive.mount("/content/drive", force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !nvidia-smi
# !pip install -U git+https://github.com/qubvel/efficientnet

# %%
# %tensorflow_version 2.x

from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.utils import to_categorical, plot_model
import tensorflow.keras.callbacks as cb
import tensorflow.keras.layers as L
import tensorflow.keras as K
import tensorflow as tf
import tensorflow_addons as tfa

import efficientnet.tfkeras as efn
import matplotlib.pyplot as plt
import numpy as np
from tqdm.auto import tqdm
from glob import glob
import os, zipfile, cv2, csv, shutil

# tf.keras.backend.set_learning_phase(True)

# %% [markdown]
# # 載入資料
#         # Coefficients:   width,depth,res,dropout
#         'efficientnet-b0': (1.0, 1.0, 224, 0.2),
#         'efficientnet-b1': (1.0, 1.1, 240, 0.2),
#         'efficientnet-b2': (1.1, 1.2, 260, 0.3),
#         'efficientnet-b3': (1.2, 1.4, 300, 0.3),
#         'efficientnet-b4': (1.4, 1.8, 380, 0.4),
#         'efficientnet-b5': (1.6, 2.2, 456, 0.4),
#         'efficientnet-b6': (1.8, 2.6, 528, 0.5),
#         'efficientnet-b7': (2.0, 3.1, 600, 0.5),

# %%
IMAGE_SIZE = 224
BATCH_SIZE = 32
NUM_EPOCHS = 100
STEPS = 128
NUM_CLASSES = 3
DATASET_PATH = '/content/datasets'       # 資料路徑

# %%
if not os.path.exists('dataset_8'):
    f = zipfile.ZipFile("/content/drive/My Drive/Colab Notebooks/datasets-8-2.zip")
    f.extractall("./")

# %% [markdown]
# # 資料增強 ImageDataGenerator

# %%
# [-1, 1]
def preprocess_fn1(im_array):
    return im_array / 127.5 -1

# 平均 / 標準差
def preprocess_fn3(im_array):
    return (im_array - np.mean(im_array))/ np.std(im_array)

trn_dagen = ImageDataGenerator(rotation_range=40,
                               width_shift_range=0.2,
                               height_shift_range=0.2,
                            #    shear_range=0.2,
                               zoom_range=0.2,
                            #    channel_shift_range=10,
                               horizontal_flip=True,
                            #    brightness_range= [0.1, 10],
                               preprocessing_function= preprocess_fn1,
                               fill_mode='nearest')

trn_gen = trn_dagen.flow_from_directory(os.path.join(DATASET_PATH, 'train'),
                                        target_size=(IMAGE_SIZE, IMAGE_SIZE),
                                        batch_size=BATCH_SIZE,
                                        class_mode='categorical',
                                        shuffle=True)

val_eva_dagen = ImageDataGenerator(preprocessing_function= preprocess_fn1)

val_gen = val_eva_dagen.flow_from_directory(os.path.join(DATASET_PATH, 'test'),
                                            target_size=(IMAGE_SIZE, IMAGE_SIZE),
                                            batch_size= BATCH_SIZE,
                                            class_mode='categorical',
                                            shuffle=True)
# Out:
# Found 7204 images belonging to 3 classes.
# Found 475 images belonging to 3 classes.

# %% [markdown]
# # 動態設計 Learning rate

# %%
def lrfn(epoch):
    LR_START = 0.0001
    LR_MAX = 0.00005
    LR_MIN = 0.0001
    LR_RAMPUP_EPOCHS = 4
    LR_SUSTAIN_EPOCHS = 6
    LR_EXP_DECAY = .8

    if epoch < LR_RAMPUP_EPOCHS:
        lr = (LR_MAX - LR_START) / LR_RAMPUP_EPOCHS * epoch + LR_START
    elif epoch < LR_RAMPUP_EPOCHS + LR_SUSTAIN_EPOCHS:
        lr = LR_MAX
    else:
        lr = (LR_MAX - LR_MIN) * LR_EXP_DECAY**(epoch - LR_RAMPUP_EPOCHS - LR_SUSTAIN_EPOCHS) + LR_MIN
    return lr
    
lr_callback = cb.LearningRateScheduler(lrfn, verbose=True)

rl_callback = cb.ReduceLROnPlateau(monitor = "loss", 
                                   factor = 0.1, 
                                   patience = 3, 
                                   verbose = 0, 
                                   mode = "auto", 
                                   min_delta = 1e-4, 
                                   cooldown = 0, 
                                   min_lr = 1e-7)

mc_callback = cb.ModelCheckpoint('drive/My Drive/ep{epoch:03d}-loss{loss:.3f}-val_loss{val_loss:.3f}.h5',
                                 monitor='loss',
                                 save_weights_only=True, 
                                 save_best_only=True, 
                                 save_freq=1)

es_callback = cb.EarlyStopping(patience=15, restore_best_weights=True)

# rng = [i for i in range(NUM_EPOCHS)]
# y = [lrfn(x) for x in rng]
# plt.plot(rng, y)
# print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))

callbacks = [
             lr_callback, 
             rl_callback, 
            #  mc_callback,
             es_callback
             ]

# %% [markdown]
# # CNN、FC 模型建立

# %%
net = efn.EfficientNetB5(input_shape= (IMAGE_SIZE, IMAGE_SIZE, 3),
                         weights= 'noisy-student',
                         include_top= False)

for layer in net.layers:
    layer.trainable = True

x = net.output
x = L.GlobalMaxPooling2D()(x)
out = L.Dense(NUM_CLASSES, activation='softmax')(x)

model = Model(inputs=net.input, outputs=out)
# Out:
# Downloading data from https://github.com/qubvel/efficientnet/releases/download/v0.0.1/efficientnet-b5_noisy-student_notop.h5
# 115261440/115255328 [==============================] - 1s 0us/step

# %% [markdown]
# # 模型編譯 optimizer、loss、metrics

# %%
import tensorflow.keras as K

model.compile(loss=K.losses.CategoricalCrossentropy(), 
              optimizer=K.optimizers.Adam(learning_rate=1e-4, amsgrad=True), 
              metrics=[K.metrics.CategoricalAccuracy()])

# %% [markdown]
# # 模型訓練

# %%
STEP_SIZE_TRAIN = trn_gen.n // NUM_EPOCHS
STEP_SIZE_VALID = val_gen.n // NUM_EPOCHS

history = model.fit(trn_gen,
                    steps_per_epoch= STEP_SIZE_TRAIN,
                    epochs= NUM_EPOCHS,
                    verbose= 1,
                    validation_data= val_gen,
                    validation_steps= STEP_SIZE_VALID,
                    callbacks= callbacks)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 1/100
# 72/72 [==============================] - 61s 847ms/step - loss: 1.3930 - categorical_accuracy: 0.5202 - val_loss: 1.5555 - val_categorical_accuracy: 0.5000 - lr: 1.0000e-04
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 8.75e-05.
# Epoch 2/100
# 72/72 [==============================] - 59s 814ms/step - loss: 0.8513 - categorical_accuracy: 0.6736 - val_loss: 0.8328 - val_categorical_accuracy: 0.6797 - lr: 8.7500e-05
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 7.500000000000001e-05.
# Epoch 3/100
# 72/72 [==============================] - 59s 813ms/step - loss: 0.7769 - categorical_accuracy: 0.6957 - val_loss: 0.6269 - val_categorical_accuracy: 0.6953 - lr: 7.5000e-05
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 6.25e-05.
# Epoch 4/100
# 72/72 [==============================] - 59s 816ms/step - loss: 0.7463 - categorical_accuracy: 0.7101 - val_loss: 0.6386 - val_categorical_accuracy: 0.7422 - lr: 6.2500e-05
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 5e-05.
# Epoch 5/100
# 72/72 [==============================] - 59s 820ms/step - loss: 0.6649 - categorical_accuracy: 0.7405 - val_loss: 0.6703 - val_categorical_accuracy: 0.7109 - lr: 5.0000e-05
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 5e-05.
# Epoch 6/100
# 72/72 [==============================] - 59s 823ms/step - loss: 0.6632 - categorical_accuracy: 0.7218 - val_loss: 0.5226 - val_categorical_accuracy: 0.7656 - lr: 5.0000e-05
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 5e-05.
# Epoch 7/100
# 72/72 [==============================] - 59s 820ms/step - loss: 0.6546 - categorical_accuracy: 0.7161 - val_loss: 0.5725 - val_categorical_accuracy: 0.7500 - lr: 5.0000e-05
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 5e-05.
# Epoch 8/100
# 72/72 [==============================] - 59s 821ms/step - loss: 0.5662 - categorical_accuracy: 0.7669 - val_loss: 0.4231 - val_categorical_accuracy: 0.8203 - lr: 5.0000e-05
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 5e-05.
# Epoch 9/100
# 72/72 [==============================] - 59s 821ms/step - loss: 0.5634 - categorical_accuracy: 0.7652 - val_loss: 0.4301 - val_categorical_accuracy: 0.7969 - lr: 5.0000e-05
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 5e-05.
# Epoch 10/100
# 72/72 [==============================] - 59s 816ms/step - loss: 0.5495 - categorical_accuracy: 0.7691 - val_loss: 0.5066 - val_categorical_accuracy: 0.7969 - lr: 5.0000e-05
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 5e-05.
# Epoch 11/100
# 72/72 [==============================] - 59s 814ms/step - loss: 0.5600 - categorical_accuracy: 0.7597 - val_loss: 0.5004 - val_categorical_accuracy: 0.7812 - lr: 5.0000e-05
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 6e-05.
# Epoch 12/100
# 72/72 [==============================] - 59s 819ms/step - loss: 0.5328 - categorical_accuracy: 0.7808 - val_loss: 0.4771 - val_categorical_accuracy: 0.8203 - lr: 6.0000e-05
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 6.8e-05.
# Epoch 13/100
# 72/72 [==============================] - 59s 818ms/step - loss: 0.5110 - categorical_accuracy: 0.7860 - val_loss: 0.4592 - val_categorical_accuracy: 0.7891 - lr: 6.8000e-05
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 7.439999999999999e-05.
# Epoch 14/100
# 72/72 [==============================] - 59s 814ms/step - loss: 0.5010 - categorical_accuracy: 0.7865 - val_loss: 0.5333 - val_categorical_accuracy: 0.7734 - lr: 7.4400e-05
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 7.952e-05.
# Epoch 15/100
# 72/72 [==============================] - 58s 810ms/step - loss: 0.5080 - categorical_accuracy: 0.7925 - val_loss: 0.5497 - val_categorical_accuracy: 0.7500 - lr: 7.9520e-05
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 8.361600000000001e-05.
# Epoch 16/100
# 72/72 [==============================] - 58s 811ms/step - loss: 0.4925 - categorical_accuracy: 0.7917 - val_loss: 0.4162 - val_categorical_accuracy: 0.8203 - lr: 8.3616e-05
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 8.68928e-05.
# Epoch 17/100
# 72/72 [==============================] - 58s 811ms/step - loss: 0.4997 - categorical_accuracy: 0.7778 - val_loss: 0.5459 - val_categorical_accuracy: 0.7578 - lr: 8.6893e-05
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 8.951424e-05.
# Epoch 18/100
# 72/72 [==============================] - 59s 814ms/step - loss: 0.4690 - categorical_accuracy: 0.8069 - val_loss: 0.4098 - val_categorical_accuracy: 0.8203 - lr: 8.9514e-05
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 9.161139199999999e-05.
# Epoch 19/100
# 72/72 [==============================] - 59s 817ms/step - loss: 0.4668 - categorical_accuracy: 0.8077 - val_loss: 0.4456 - val_categorical_accuracy: 0.8281 - lr: 9.1611e-05
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 9.32891136e-05.
# Epoch 20/100
# 72/72 [==============================] - 59s 815ms/step - loss: 0.4811 - categorical_accuracy: 0.8027 - val_loss: 0.4565 - val_categorical_accuracy: 0.8203 - lr: 9.3289e-05
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 9.463129088e-05.
# Epoch 21/100
# 72/72 [==============================] - 59s 815ms/step - loss: 0.4512 - categorical_accuracy: 0.8142 - val_loss: 0.3570 - val_categorical_accuracy: 0.8516 - lr: 9.4631e-05
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 9.5705032704e-05.
# Epoch 22/100
# 72/72 [==============================] - 59s 817ms/step - loss: 0.4534 - categorical_accuracy: 0.8060 - val_loss: 0.3723 - val_categorical_accuracy: 0.8125 - lr: 9.5705e-05
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 9.65640261632e-05.
# Epoch 23/100
# 72/72 [==============================] - 59s 818ms/step - loss: 0.4622 - categorical_accuracy: 0.8069 - val_loss: 0.4637 - val_categorical_accuracy: 0.7891 - lr: 9.6564e-05
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 9.725122093056e-05.
# Epoch 24/100
# 72/72 [==============================] - 58s 810ms/step - loss: 0.4244 - categorical_accuracy: 0.8256 - val_loss: 0.3778 - val_categorical_accuracy: 0.8359 - lr: 9.7251e-05
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 9.780097674444801e-05.
# Epoch 25/100
# 72/72 [==============================] - 59s 815ms/step - loss: 0.4092 - categorical_accuracy: 0.8242 - val_loss: 0.4782 - val_categorical_accuracy: 0.7969 - lr: 9.7801e-05
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 9.82407813955584e-05.
# Epoch 26/100
# 72/72 [==============================] - 59s 814ms/step - loss: 0.4047 - categorical_accuracy: 0.8370 - val_loss: 0.4246 - val_categorical_accuracy: 0.8047 - lr: 9.8241e-05
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 9.859262511644672e-05.
# Epoch 27/100
# 72/72 [==============================] - 59s 814ms/step - loss: 0.4139 - categorical_accuracy: 0.8344 - val_loss: 0.3957 - val_categorical_accuracy: 0.8281 - lr: 9.8593e-05
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 9.887410009315738e-05.
# Epoch 28/100
# 72/72 [==============================] - 59s 814ms/step - loss: 0.4033 - categorical_accuracy: 0.8260 - val_loss: 0.4543 - val_categorical_accuracy: 0.8125 - lr: 9.8874e-05
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 9.90992800745259e-05.
# Epoch 29/100
# 72/72 [==============================] - 59s 817ms/step - loss: 0.4030 - categorical_accuracy: 0.8351 - val_loss: 0.3233 - val_categorical_accuracy: 0.8750 - lr: 9.9099e-05
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 9.927942405962072e-05.
# Epoch 30/100
# 72/72 [==============================] - 58s 812ms/step - loss: 0.3775 - categorical_accuracy: 0.8392 - val_loss: 0.4148 - val_categorical_accuracy: 0.8281 - lr: 9.9279e-05
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 9.942353924769659e-05.
# Epoch 31/100
# 72/72 [==============================] - 59s 814ms/step - loss: 0.3840 - categorical_accuracy: 0.8368 - val_loss: 0.3594 - val_categorical_accuracy: 0.8516 - lr: 9.9424e-05
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 9.953883139815726e-05.
# Epoch 32/100
# 72/72 [==============================] - 58s 808ms/step - loss: 0.3946 - categorical_accuracy: 0.8352 - val_loss: 0.4494 - val_categorical_accuracy: 0.8359 - lr: 9.9539e-05
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 9.963106511852581e-05.
# Epoch 33/100
# 72/72 [==============================] - 59s 825ms/step - loss: 0.3879 - categorical_accuracy: 0.8355 - val_loss: 0.3663 - val_categorical_accuracy: 0.8438 - lr: 9.9631e-05
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 9.970485209482065e-05.
# Epoch 34/100
# 72/72 [==============================] - 59s 820ms/step - loss: 0.3759 - categorical_accuracy: 0.8390 - val_loss: 0.3998 - val_categorical_accuracy: 0.8125 - lr: 9.9705e-05
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 9.976388167585652e-05.
# Epoch 35/100
# 72/72 [==============================] - 59s 818ms/step - loss: 0.3732 - categorical_accuracy: 0.8420 - val_loss: 0.4344 - val_categorical_accuracy: 0.8281 - lr: 9.9764e-05
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 9.981110534068521e-05.
# Epoch 36/100
# 72/72 [==============================] - 59s 818ms/step - loss: 0.3947 - categorical_accuracy: 0.8335 - val_loss: 0.3426 - val_categorical_accuracy: 0.8516 - lr: 9.9811e-05
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 9.984888427254818e-05.
# Epoch 37/100
# 72/72 [==============================] - 59s 821ms/step - loss: 0.3548 - categorical_accuracy: 0.8568 - val_loss: 0.4358 - val_categorical_accuracy: 0.7812 - lr: 9.9849e-05
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 9.987910741803855e-05.
# Epoch 38/100
# 72/72 [==============================] - 59s 822ms/step - loss: 0.3933 - categorical_accuracy: 0.8453 - val_loss: 0.2579 - val_categorical_accuracy: 0.8984 - lr: 9.9879e-05
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 9.990328593443083e-05.
# Epoch 39/100
# 72/72 [==============================] - 58s 812ms/step - loss: 0.3480 - categorical_accuracy: 0.8642 - val_loss: 0.3705 - val_categorical_accuracy: 0.8594 - lr: 9.9903e-05
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 9.992262874754467e-05.
# Epoch 40/100
# 72/72 [==============================] - 59s 816ms/step - loss: 0.3635 - categorical_accuracy: 0.8480 - val_loss: 0.3950 - val_categorical_accuracy: 0.8281 - lr: 9.9923e-05
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 9.993810299803574e-05.
# Epoch 41/100
# 72/72 [==============================] - 58s 811ms/step - loss: 0.3546 - categorical_accuracy: 0.8519 - val_loss: 0.3547 - val_categorical_accuracy: 0.8594 - lr: 9.9938e-05
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 9.995048239842859e-05.
# Epoch 42/100
# 72/72 [==============================] - 58s 811ms/step - loss: 0.3344 - categorical_accuracy: 0.8750 - val_loss: 0.4409 - val_categorical_accuracy: 0.8047 - lr: 9.9950e-05
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 9.996038591874287e-05.
# Epoch 43/100
# 72/72 [==============================] - 59s 819ms/step - loss: 0.3563 - categorical_accuracy: 0.8503 - val_loss: 0.3700 - val_categorical_accuracy: 0.8203 - lr: 9.9960e-05
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 9.99683087349943e-05.
# Epoch 44/100
# 72/72 [==============================] - 59s 815ms/step - loss: 0.3390 - categorical_accuracy: 0.8637 - val_loss: 0.3550 - val_categorical_accuracy: 0.8672 - lr: 9.9968e-05
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 9.997464698799543e-05.
# Epoch 45/100
# 72/72 [==============================] - 58s 812ms/step - loss: 0.3571 - categorical_accuracy: 0.8515 - val_loss: 0.5242 - val_categorical_accuracy: 0.7344 - lr: 9.9975e-05
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 9.997971759039635e-05.
# Epoch 46/100
# 72/72 [==============================] - 59s 817ms/step - loss: 0.3359 - categorical_accuracy: 0.8594 - val_loss: 0.2989 - val_categorical_accuracy: 0.8906 - lr: 9.9980e-05
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 9.998377407231709e-05.
# Epoch 47/100
# 72/72 [==============================] - 59s 813ms/step - loss: 0.3447 - categorical_accuracy: 0.8598 - val_loss: 0.3684 - val_categorical_accuracy: 0.8438 - lr: 9.9984e-05
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 9.998701925785367e-05.
# Epoch 48/100
# 72/72 [==============================] - 58s 810ms/step - loss: 0.3144 - categorical_accuracy: 0.8686 - val_loss: 0.3615 - val_categorical_accuracy: 0.8438 - lr: 9.9987e-05
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 9.998961540628293e-05.
# Epoch 49/100
# 72/72 [==============================] - 58s 812ms/step - loss: 0.3103 - categorical_accuracy: 0.8735 - val_loss: 0.3974 - val_categorical_accuracy: 0.8281 - lr: 9.9990e-05
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 9.999169232502635e-05.
# Epoch 50/100
# 72/72 [==============================] - 58s 812ms/step - loss: 0.3259 - categorical_accuracy: 0.8641 - val_loss: 0.3200 - val_categorical_accuracy: 0.8906 - lr: 9.9992e-05
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 9.999335386002108e-05.
# Epoch 51/100
# 72/72 [==============================] - 58s 812ms/step - loss: 0.3027 - categorical_accuracy: 0.8798 - val_loss: 0.4041 - val_categorical_accuracy: 0.8438 - lr: 9.9993e-05
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 9.999468308801686e-05.
# Epoch 52/100
# 72/72 [==============================] - 58s 805ms/step - loss: 0.2818 - categorical_accuracy: 0.8837 - val_loss: 0.4212 - val_categorical_accuracy: 0.8203 - lr: 9.9995e-05
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 9.99957464704135e-05.
# Epoch 53/100
# 72/72 [==============================] - 58s 809ms/step - loss: 0.3111 - categorical_accuracy: 0.8726 - val_loss: 0.4041 - val_categorical_accuracy: 0.8281 - lr: 9.9996e-05

# %%
model.save('/content/drive/My Drive/mango_v6-4.h5')
# model = tf.keras.models.load_model('/content/drive/My Drive/mango_v6.h5')

# %% [markdown]
# # Plot accuracy

# %%
plt.plot(history.history['categorical_accuracy'])
plt.plot(history.history['val_categorical_accuracy'])
plt.legend(['acc', 'val_acc'])
plt.title('acc')
# Out:
# Text(0.5, 1.0, 'acc')

# %% [markdown]
# # Plot loss

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['loss', 'val_loss'])
plt.title('loss')
# Out:
# Text(0.5, 1.0, 'loss')
